# %% [markdown]
# # week 2: Assignment

# %% [markdown]
# ## 1. Loading data

# %%
import graphlab

# %%
sales = graphlab.SFrame('home_data.gl')
train_data,test_data = sales.random_split(0.8,seed=0)
# Out:
# [INFO] This non-commercial license of GraphLab Create is assigned to jessherlock@sjtu.edu.cnand will expire on October 13, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-5369 - Server binary: /Library/Python/2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1444888586.log
# [INFO] GraphLab Server Version: 1.6.1

# %%
graphlab.canvas.set_target('ipynb')
sales.show(view="Scatter Plot", x="sqft_living", y="price")

# %%
sales.show(view='BoxWhisker Plot', x='zipcode', y='price')

# %% [markdown]
# * zipcode with highest average price: 98039

# %% [markdown]
# ## 2. Selection and summary statistics

# %%
selected_houses = sales[sales['zipcode']=='98039']

# %%
selected_houses['price'].mean()
# Out:
# 2160606.5999999996

# %% [markdown]
# ### Answer for Question 1: 2160606.5999999996

# %% [markdown]
# ## 3. Filtering data

# %%
filtered_houses = sales[(sales['sqft_living'] > 2000) & (sales['sqft_living'] <= 4000)]

# %%
filtered_houses.shape
# Out:
# (9118, 21)

# %%
sales.shape
# Out:
# (21613, 21)

# %%
fraction = float(9118)/21613
print fraction
# Out:
# 0.421875722945

# %% [markdown]
# ### Answer for Question 2:  0.421875722945

# %%
advanced_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode',
'condition', # condition of house
'grade', # measure of quality of construction
'waterfront', # waterfront property	
'view', # type of view				
'sqft_above', # square feet above ground				
'sqft_basement', # square feet in basement				
'yr_built', # the year built				
'yr_renovated', # the year renovated				
'lat', 'long', # the lat-long of the parcel				
'sqft_living15', # average sq.ft. of 15 nearest neighbors 				
'sqft_lot15', # average lot size of 15 nearest neighbors 
]

# %%
advanced_features_model = graphlab.linear_regression.create(train_data,target='price',
                                                           features=advanced_features,
                                                           validation_set=None)
# Out:
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 17384
# PROGRESS: Number of features          : 18
# PROGRESS: Number of unpacked features : 18
# PROGRESS: Number of coefficients    : 127
# PROGRESS: Starting Newton Method
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+
# PROGRESS: | 1         | 2        | 0.112577     | 3469012.450686     | 154580.940736 |
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+

# %%
print advanced_features_model.evaluate(test_data)
# Out:
# {'max_error': 3556849.413858208, 'rmse': 156831.1168021901}

# %%
my_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode']
my_features_model = graphlab.linear_regression.create(train_data, target='price', 
                                                      features=my_features,
                                                     validation_set=None)
# Out:
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 17384
# PROGRESS: Number of features          : 6
# PROGRESS: Number of unpacked features : 6
# PROGRESS: Number of coefficients    : 115
# PROGRESS: Starting Newton Method
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+
# PROGRESS: | 1         | 2        | 0.071536     | 3763208.270523     | 181908.848367 |
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+

# %%
my_features_model.evaluate(test_data)
# Out:
# {'max_error': 3486584.509381705, 'rmse': 179542.4333126903}

# %%
advanced_features_model.evaluate(test_data)
# Out:
# {'max_error': 3556849.413858208, 'rmse': 156831.1168021901}

# %%
rmse_diff = 179542.4333126903 - 156831.1168021901

# %%
rmse_diff
# Out:
# 22711.316510500183

# %% [markdown]
# ### Answer for Question 3: 22711.316510500183
